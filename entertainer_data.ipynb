# %%
import pandas as pd

# %%
#a = Entertainer Basic info
#b = entertainer breakthrough
#c = entertainer lastwork

# %%
basic_info = pd.read_excel('C:/Users/Manisha/OneDrive/Desktop/data analysis project/Entertainer Data Analysis/Entertainer - Basic Info.xlsx')

# %%
basic_info.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
EntertainerBT= pd.read_excel("C:/Users/Manisha/OneDrive/Desktop/data analysis project/Entertainer Data Analysis/Entertainer - Breakthrough Info.xlsx")

# %%
EntertainerBT.drop('Entertainer',inplace = True, axis=1)

# %%
EntertainerBT.head()
# Out:
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %%
lastwork= pd.read_excel(r"C:\Users\Manisha\OneDrive\Desktop\data analysis project\Entertainer Data Analysis\Entertainer - Last work Info.xlsx")

# %%
lastwork.drop('Entertainer',inplace = True, axis=1)

# %%
lastwork.head()
# Out:
#    Year of Last Major Work (arguable)  Year of Death
# 0                                2016            NaN
# 1                                2016            NaN
# 2                                2014            NaN
# 3                                1989         1989.0
# 4                                2016            NaN

# %%
main1 = pd.concat([basic_info,EntertainerBT],axis=1)

# %%
main1.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
main= pd.concat([main1,lastwork],axis=1)

# %%
main.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
new_file = 'main_data.xlsx'

# %%
main.to_excel(new_file)
